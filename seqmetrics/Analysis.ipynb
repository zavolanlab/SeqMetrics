# %%
# If package installed with `pip install -e .`, this should work:
from seqmetrics.sequence_analyzer import SequenceAnalyzer
from seqmetrics.codon_usage import CodonUsageTable
from seqmetrics.trna_weights import TRNAWeightTable
from seqmetrics.codon_definitions import SYN_CODONS_BY_AA

import pandas as pd
from pathlib import Path

# ---- user-configurable paths and names ----
FASTA_PATH = Path("s/coding_regions.fasta")  # your CDS FASTA
TISSUE_USAGE_FILE = Path("data/human_codon_usage.tsv")  # tab-delimited codon-usage
TISSUE_NAME = "Genomic"        # must match a 'Tissue' value in the table
SPECIES_NAME = "human"         # label only, unless you wire tRNA table
TRNA_TABLE_FILE = None         # set to a path if you want tAI, e.g. Path("Hsapi38-tRNAs-genes.tsv")
